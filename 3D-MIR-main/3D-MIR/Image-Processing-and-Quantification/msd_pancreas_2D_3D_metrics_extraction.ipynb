# %%
import os
import nibabel as nib
import numpy as np
import skimage
import SimpleITK as sitk
import pandas as pd
import matplotlib.pyplot as plt
import cv2, pickle

# %%
# Prototype with one subject segmentation first
print(os.getcwd())
image_path = r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\imagesTr'
tumor_path = r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr'

# Organ segmentation files obtained from TotalSegmentator v1.5.7
# Results are generated from the run_total_segmentator.py script
label_organs_path = r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_segmentation\Task07_Pancreas\imagesTr'

# List all the files in the image path and label path, exclude files that start with ._ 
image_list = [f for f in os.listdir(image_path) if not f.startswith('._') and  'nii.gz' in f]
tumor_label_value = 2
number_of_organs = 104 
# Sort the list
image_list.sort()
print(len(image_list))
# Out:
# c:\Users\ADMIN\Desktop\Workspace\Code\3D-MIR-main\Code\Image-Processing-and-Quantification
# 281

# %%
import os
import pickle
import numpy as np
import SimpleITK as sitk

image_id_dict = {}
for image_name in image_list:
    label_organ_file = os.path.join(label_organs_path, image_name)
    label_organ = sitk.ReadImage(label_organ_file)
    img_emb_list = []

    # Get 3D matrix from the image
    label_organ_data = sitk.GetArrayFromImage(label_organ)

    for i in range(label_organ_data.shape[0]):
        label_slice = label_organ_data[i, :, :]
        # For label slice, create a dictionary where the key is the pixel value and the value is the number of pixels different from 0
        label_dict = dict(zip(*np.unique(label_slice, return_counts=True)))
        label_vector = np.zeros(104, dtype=int)
        for key, value in label_dict.items():
            if key > 0 and key - 1 < len(label_vector):
                label_vector[key - 1] = value

        img_emb_list.append(label_vector)

    # concatenate the vectors into a matrix
    full_emb = np.stack(img_emb_list, axis=0)
    image_id_dict[image_name] = full_emb.copy()

output_file = r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_2D_per_organ.pkl'
os.makedirs(os.path.dirname(output_file), exist_ok=True)

with open(output_file, "wb") as f:
    pickle.dump(image_id_dict, f)
print("Saved file: ", output_file)
# Out:
# Saved file:  C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_2D_per_organ.pkl

# %%
output_file = r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_2D_per_organ.pkl'
# Load pickle file
with open(output_file, "rb") as f:
    data_dict = pickle.load(f)
data_dict.keys()
# Out:
# dict_keys(['pancreas_001.nii.gz', 'pancreas_004.nii.gz', 'pancreas_005.nii.gz', 'pancreas_006.nii.gz', 'pancreas_010.nii.gz', 'pancreas_012.nii.gz', 'pancreas_015.nii.gz', 'pancreas_016.nii.gz', 'pancreas_018.nii.gz', 'pancreas_019.nii.gz', 'pancreas_021.nii.gz', 'pancreas_024.nii.gz', 'pancreas_025.nii.gz', 'pancreas_028.nii.gz', 'pancreas_029.nii.gz', 'pancreas_032.nii.gz', 'pancreas_035.nii.gz', 'pancreas_037.nii.gz', 'pancreas_040.nii.gz', 'pancreas_041.nii.gz', 'pancreas_042.nii.gz', 'pancreas_043.nii.gz', 'pancreas_045.nii.gz', 'pancreas_046.nii.gz', 'pancreas_048.nii.gz', 'pancreas_049.nii.gz', 'pancreas_050.nii.gz', 'pancreas_051.nii.gz', 'pancreas_052.nii.gz', 'pancreas_055.nii.gz', 'pancreas_056.nii.gz', 'pancreas_058.nii.gz', 'pancreas_061.nii.gz', 'pancreas_064.nii.gz', 'pancreas_066.nii.gz', 'pancreas_067.nii.gz', 'pancreas_069.nii.gz', 'pancreas_070.nii.gz', 'pancreas_071.nii.gz', 'pancreas_074.nii.gz', 'pancreas_075.nii.gz', 'pancreas_077.nii.gz', 'pancreas_078.nii.gz', 'pancreas_080.nii.gz', 'pancreas_081.nii.gz', 'pancreas_083.nii.gz', 'pancreas_084.nii.gz', 'pancreas_086.nii.gz', 'pancreas_087.nii.gz', 'pancreas_088.nii.gz', 'pancreas_089.nii.gz', 'pancreas_091.nii.gz', 'pancreas_092.nii.gz', 'pancreas_093.nii.gz', 'pancreas_094.nii.gz', 'pancreas_095.nii.gz', 'pancreas_096.nii.gz', 'pancreas_098.nii.gz', 'pancreas_099.nii.gz', 'pancreas_100.nii.gz', 'pancreas_101.nii.gz', 'pancreas_102.nii.gz', 'pancreas_103.nii.gz', 'pancreas_104.nii.gz', 'pancreas_105.nii.gz', 'pancreas_106.nii.gz', 'pancreas_107.nii.gz', 'pancreas_109.nii.gz', 'pancreas_110.nii.gz', 'pancreas_111.nii.gz', 'pancreas_113.nii.gz', 'pancreas_114.nii.gz', 'pancreas_117.nii.gz', 'pancreas_119.nii.gz', 'pancreas_120.nii.gz', 'pancreas_122.nii.gz', 'pancreas_124.nii.gz', 'pancreas_125.nii.gz', 'pancreas_126.nii.gz', 'pancreas_127.nii.gz', 'pancreas_129.nii.gz', 'pancreas_130.nii.gz', 'pancreas_131.nii.gz', 'pancreas_135.nii.gz', 'pancreas_137.nii.gz', 'pancreas_138.nii.gz', 'pancreas_140.nii.gz', 'pancreas_145.nii.gz', 'pancreas_147.nii.gz', 'pancreas_148.nii.gz', 'pancreas_149.nii.gz', 'pancreas_155.nii.gz', 'pancreas_157.nii.gz', 'pancreas_158.nii.gz', 'pancreas_159.nii.gz', 'pancreas_160.nii.gz', 'pancreas_165.nii.gz', 'pancreas_166.nii.gz', 'pancreas_167.nii.gz', 'pancreas_169.nii.gz', 'pancreas_170.nii.gz', 'pancreas_172.nii.gz', 'pancreas_173.nii.gz', 'pancreas_175.nii.gz', 'pancreas_178.nii.gz', 'pancreas_179.nii.gz', 'pancreas_180.nii.gz', 'pancreas_181.nii.gz', 'pancreas_182.nii.gz', 'pancreas_183.nii.gz', 'pancreas_186.nii.gz', 'pancreas_187.nii.gz', 'pancreas_191.nii.gz', 'pancreas_193.nii.gz', 'pancreas_194.nii.gz', 'pancreas_196.nii.gz', 'pancreas_197.nii.gz', 'pancreas_198.nii.gz', 'pancreas_199.nii.gz', 'pancreas_200.nii.gz', 'pancreas_201.nii.gz', 'pancreas_203.nii.gz', 'pancreas_204.nii.gz', 'pancreas_207.nii.gz', 'pancreas_209.nii.gz', 'pancreas_210.nii.gz', 'pancreas_211.nii.gz', 'pancreas_212.nii.gz', 'pancreas_213.nii.gz', 'pancreas_214.nii.gz', 'pancreas_215.nii.gz', 'pancreas_217.nii.gz', 'pancreas_218.nii.gz', 'pancreas_219.nii.gz', 'pancreas_222.nii.gz', 'pancreas_224.nii.gz', 'pancreas_225.nii.gz', 'pancreas_226.nii.gz', 'pancreas_227.nii.gz', 'pancreas_228.nii.gz', 'pancreas_229.nii.gz', 'pancreas_230.nii.gz', 'pancreas_231.nii.gz', 'pancreas_234.nii.gz', 'pancreas_235.nii.gz', 'pancreas_236.nii.gz', 'pancreas_239.nii.gz', 'pancreas_241.nii.gz', 'pancreas_242.nii.gz', 'pancreas_243.nii.gz', 'pancreas_244.nii.gz', 'pancreas_246.nii.gz', 'pancreas_247.nii.gz', 'pancreas_249.nii.gz', 'pancreas_253.nii.gz', 'pancreas_254.nii.gz', 'pancreas_255.nii.gz', 'pancreas_256.nii.gz', 'pancreas_258.nii.gz', 'pancreas_259.nii.gz', 'pancreas_261.nii.gz', 'pancreas_262.nii.gz', 'pancreas_264.nii.gz', 'pancreas_265.nii.gz', 'pancreas_266.nii.gz', 'pancreas_267.nii.gz', 'pancreas_268.nii.gz', 'pancreas_269.nii.gz', 'pancreas_270.nii.gz', 'pancreas_274.nii.gz', 'pancreas_275.nii.gz', 'pancreas_276.nii.gz', 'pancreas_277.nii.gz', 'pancreas_ ...

# %%
import tqdm

# Create a dataframe to store the metrics per file and 2D image
df2d = pd.DataFrame(columns=['filename', 'slice', 'cancer_stage', 'tumor_area'] )
df3d = pd.DataFrame(columns=['filename','cancer_stage'])

# #iterate through the list of files image_list and label_list
# for image_name, label_name in tqdm.tqdm(zip(image_list, label_list)):
(stats_list_2d, stats_list_3d) = ([], [])
for image_name in image_list: 
#for image_name in tqdm.tqdm(image_list):
    print(image_name)

    (image_file, tumor_file, organs_file) = (os.path.join(image_path, image_name), os.path.join(tumor_path, image_name), os.path.join(label_organs_path, image_name))
    (image, tumor, organs) = (sitk.ReadImage(image_file), sitk.ReadImage(tumor_file), sitk.ReadImage(organs_file))

    # Cast tumor to int8 using CastImageFilter to uint8
    castFilter = sitk.CastImageFilter()
    castFilter.SetOutputPixelType(sitk.sitkUInt8)
    tumor = castFilter.Execute(tumor)

    (image_data, tumor_data, organs_data) = (sitk.GetArrayFromImage(image), sitk.GetArrayFromImage(tumor), sitk.GetArrayFromImage(organs))
    spacing = image.GetSpacing()

    # For tumor image make zero voxels except for tumor label, pancreas seems the exception from other msd cohorts
    tumor_data[tumor_data != tumor_label_value] = 0
    tumor_data[tumor_data == tumor_label_value] = 1

    #Get pixel type for organs
    pixel_type = tumor.GetPixelIDTypeAsString()
    tumor = sitk.GetImageFromArray(tumor_data)

    cc = sitk.ConnectedComponent(tumor)
    stats = sitk.LabelIntensityStatisticsImageFilter()
    stats.Execute(cc, tumor)
    print(tumor_file, stats.GetNumberOfLabels())
    # Get array of connected component numbers
    cc_tumor_array = sitk.GetArrayFromImage(cc)

    # Creates dictionary where key is tuple consisting of subject ID and label number
    #tumor_size_list = []
    for l in stats.GetLabels():
        # Ignore if number of voxels is less than 6

        # Remove spurius or flat objects objects 
        if stats.GetNumberOfPixels(l) < 3 or stats.GetBoundingBox(l)[-1] == 1:
            cc_tumor_array[cc_tumor_array == l] = 0
            continue

        # Count number of voxels in this connected component
        voxel_count = np.sum(cc_tumor_array == l)
        #Initialize dictionary containing different metrics
        cc_dictionary = {}
        cc_dictionary['image_name'] = image_name
        cc_dictionary['PhysicalSize_cm3'] = stats.GetPhysicalSize(l) * spacing[0] * spacing[1] * spacing[2] / 1000
        cc_dictionary['NumberOfVoxels'] = stats.GetNumberOfPixels(l)
        cc_dictionary['Roundness'] = stats.GetRoundness(l)
        cc_dictionary['Elongation'] = stats.GetElongation(l)
        cc_dictionary['Flatness'] = stats.GetFlatness(l)
        cc_dictionary['EquivalentSphericalRadius_cm'] = stats.GetEquivalentSphericalRadius(l)/10
        cc_dictionary['EquivalentSphericalPerimeter_cm'] = stats.GetEquivalentSphericalPerimeter(l)/10
        cc_dictionary['EquivalentEllipsoidDiameter'] = stats.GetEquivalentEllipsoidDiameter(l)
        cc_dictionary['major_axis_length_cm'] = max(stats.GetEquivalentEllipsoidDiameter(l)) / 10
        cc_dictionary['centroid'] = stats.GetCentroid(l)
        cc_dictionary['bounding_box'] = stats.GetBoundingBox(l)
        cc_dictionary['spacing']= spacing

        # Get the number of voxels in the tumor that are in the organ
        tumor_bbox = stats.GetBoundingBox(l)
        # Get voxels only in the tumor bounding box
        (x0,y0,z0,x1,y1,z1)= tumor_bbox
        # Add the width, height and depth to the x0, y0, z0
        (x1,y1,z1) = (x1+x0, y1+y0, z1+z0)
        # Coordinate systems ITK - Numpy are different:
        (organ_bbox_array, tumor_bbox_array)  = (organs_data[z0:z1, y0:y1, x0:x1], cc_tumor_array[z0:z1, y0:y1, x0:x1])

        # Quantifies tumor in each organ
        for i in range(number_of_organs+1):
            cc_dictionary['organ_'+str(i)+'_voxel_count'] = 0
            # organ_voxel_count = np.sum(np.logical_and(cc_tumor_array == l, organs_data == i))

        (voxel_values, voxel_counts) = np.unique(organ_bbox_array[tumor_bbox_array == l], return_counts=True)
        for (v,c) in zip(voxel_values, voxel_counts):
            cc_dictionary['organ_'+str(v)+'_voxel_count'] = c
        stats_list_3d.append(cc_dictionary.copy())

    # 2D Report -- Iterate through the slices
    for i in range(organs_data.shape[0]):
        tumor_slice = cc_tumor_array[i,:,:]
        organs_slice = organs_data[i,:,:]

        if not np.any(tumor_slice):
            continue

        number_of_tumors = 0
        # OpenCV returns number of objects + 1
        number_of_tumors = cv2.connectedComponents(tumor_slice.astype('uint8'),connectivity=8)[0] - 1

        # Calculate area of the tumors
        tumor_area_cm2 = np.sum(tumor_slice == 1) * spacing[0] * spacing[1] / 100

        # Localize where in the organs the tumor is
        organ_voxel_count_2d_dict = {}
        organ_voxel_count_2d_dict['filename']= image_name
        organ_voxel_count_2d_dict['slice']= i
        organ_voxel_count_2d_dict['number_of_tumors']= number_of_tumors
        organ_voxel_count_2d_dict['tumor_area_cm2']= tumor_area_cm2
        organ_voxel_count_2d_dict['spacing'] = spacing
        for i in range(number_of_organs+1):
            organ_voxel_count = np.sum(np.logical_and(tumor_slice > 0, organs_slice == i))
            organ_voxel_count_2d_dict['organ_'+str(i)+'_voxel_count'] = organ_voxel_count

        stats_list_2d.append(organ_voxel_count_2d_dict.copy())

df_tumor_report_2d = pd.DataFrame(stats_list_2d)
df_tumor_report_3d = pd.DataFrame(stats_list_3d)

df_tumor_report_3d.to_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_3D_tumor_per_organ.csv', index=False)
df_tumor_report_2d.to_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_2D_tumor_per_organ.csv', index=False)
# Out:
# pancreas_001.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_001.nii.gz 1
# pancreas_004.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_004.nii.gz 1
# pancreas_005.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_005.nii.gz 1
# pancreas_006.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_006.nii.gz 1
# pancreas_010.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_010.nii.gz 1
# pancreas_012.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_012.nii.gz 1
# pancreas_015.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_015.nii.gz 1
# pancreas_016.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_016.nii.gz 1
# pancreas_018.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_018.nii.gz 1
# pancreas_019.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_019.nii.gz 1
# pancreas_021.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_021.nii.gz 2
# pancreas_024.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_024.nii.gz 1
# pancreas_025.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_025.nii.gz 1
# pancreas_028.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_028.nii.gz 1
# pancreas_029.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_029.nii.gz 1
# pancreas_032.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_032.nii.gz 1
# pancreas_035.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_035.nii.gz 1
# pancreas_037.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_037.nii.gz 1
# pancreas_040.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_040.nii.gz 1
# pancreas_041.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_041.nii.gz 1
# pancreas_042.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_042.nii.gz 1
# pancreas_043.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_043.nii.gz 1
# pancreas_045.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_045.nii.gz 1
# pancreas_046.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_046.nii.gz 1
# pancreas_048.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_048.nii.gz 1
# pancreas_049.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_049.nii.gz 1
# pancreas_050.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_050.nii.gz 1
# pancreas_051.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_051.nii.gz 1
# pancreas_052.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_052.nii.gz 1
# pancreas_055.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_055.nii.gz 1
# pancreas_056.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_056.nii.gz 1
# pancreas_058.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_058.nii.gz 1
# pancreas_061.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_061.nii.gz 1
# pancreas_064.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_064.nii.gz 1
# pancreas_066.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_066.nii.gz 1
# pancreas_067.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_067.nii.gz 1
# pancreas_069.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_069.nii.gz 1
# pancreas_070.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_070.nii.gz 1
# pancreas_071.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_071.nii.gz 1
# pancreas_074.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_074.nii.gz 1
# pancreas_075.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_075.nii.gz 1
# pancreas_077.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_077.nii.gz 1
# pancreas_078.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_078.nii.gz 1
# pancreas_080.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_080.nii.gz 1
# pancreas_081.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_081.nii.gz 1
# pancreas_083.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_083.nii.gz 1
# pancreas_084.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_084.nii.gz 1
# pancreas_086.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_086.nii.gz 1
# pancreas_087.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_087.nii.gz 1
# pancreas_088.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_088.nii.gz 1
# pancreas_089.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_089.nii.gz 1
# pancreas_091.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_091.nii.gz 1
# pancreas_092.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_092.nii.gz 1
# pancreas_093.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_093.nii.gz 1
# pancreas_094.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_094.nii.gz 1
# pancreas_095.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_095.nii.gz 1
# pancreas_096.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_096.nii.gz 1
# pancreas_098.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_098.nii.gz 1
# pancreas_099.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_099.nii.gz 1
# pancreas_100.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_100.nii.gz 1
# pancreas_101.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_101.nii.gz 1
# pancreas_102.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_102.nii.gz 1
# pancreas_103.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_103.nii.gz 1
# pancreas_104.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_104.nii.gz 1
# pancreas_105.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_105.nii.gz 1
# pancreas_106.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_106.nii.gz 1
# pancreas_107.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_107.nii.gz 1
# pancreas_109.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_109.nii.gz 1
# pancreas_110.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_110.nii.gz 1
# pancreas_111.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_111.nii.gz 1
# pancreas_113.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_113.nii.gz 1
# pancreas_114.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_114.nii.gz 1
# pancreas_117.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_117.nii.gz 1
# pancreas_119.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_119.nii.gz 1
# pancreas_120.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_120.nii.gz 1
# pancreas_122.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_122.nii.gz 1
# pancreas_124.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_124.nii.gz 1
# pancreas_125.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_125.nii.gz 1
# pancreas_126.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_126.nii.gz 1
# pancreas_127.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_127.nii.gz 1
# pancreas_129.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_129.nii.gz 1
# pancreas_130.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_130.nii.gz 1
# pancreas_131.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_131.nii.gz 1
# pancreas_135.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_135.nii.gz 1
# pancreas_137.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_137.nii.gz 1
# pancreas_138.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_138.nii.gz 1
# pancreas_140.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_140.nii.gz 1
# pancreas_145.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_145.nii.gz 1
# pancreas_147.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_147.nii.gz 1
# pancreas_148.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_148.nii.gz 1
# pancreas_149.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_149.nii.gz 1
# pancreas_155.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_155.nii.gz 1
# pancreas_157.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_157.nii.gz 1
# pancreas_158.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_158.nii.gz 1
# pancreas_159.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_159.nii.gz 1
# pancreas_160.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_160.nii.gz 1
# pancreas_165.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_165.nii.gz 1
# pancreas_166.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_166.nii.gz 1
# pancreas_167.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_167.nii.gz 1
# pancreas_169.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_169.nii.gz 1
# pancreas_170.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_170.nii.gz 1
# pancreas_172.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_172.nii.gz 1
# pancreas_173.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_173.nii.gz 1
# pancreas_175.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_175.nii.gz 1
# pancreas_178.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_178.nii.gz 1
# pancreas_179.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_179.nii.gz 1
# pancreas_180.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_180.nii.gz 1
# pancreas_181.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_181.nii.gz 1
# pancreas_182.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_182.nii.gz 1
# pancreas_183.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_183.nii.gz 1
# pancreas_186.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_186.nii.gz 1
# pancreas_187.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_187.nii.gz 1
# pancreas_191.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_191.nii.gz 1
# pancreas_193.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_193.nii.gz 1
# pancreas_194.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_194.nii.gz 1
# pancreas_196.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_196.nii.gz 1
# pancreas_197.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_197.nii.gz 1
# pancreas_198.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_198.nii.gz 1
# pancreas_199.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_199.nii.gz 1
# pancreas_200.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_200.nii.gz 1
# pancreas_201.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_201.nii.gz 1
# pancreas_203.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_203.nii.gz 1
# pancreas_204.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_204.nii.gz 1
# pancreas_207.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_207.nii.gz 1
# pancreas_209.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_209.nii.gz 1
# pancreas_210.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_210.nii.gz 1
# pancreas_211.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_211.nii.gz 1
# pancreas_212.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_212.nii.gz 1
# pancreas_213.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_213.nii.gz 1
# pancreas_214.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_214.nii.gz 1
# pancreas_215.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_215.nii.gz 1
# pancreas_217.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_217.nii.gz 1
# pancreas_218.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_218.nii.gz 1
# pancreas_219.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_219.nii.gz 1
# pancreas_222.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_222.nii.gz 1
# pancreas_224.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_224.nii.gz 1
# pancreas_225.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_225.nii.gz 1
# pancreas_226.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_226.nii.gz 1
# pancreas_227.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_227.nii.gz 1
# pancreas_228.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_228.nii.gz 1
# pancreas_229.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_229.nii.gz 1
# pancreas_230.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_230.nii.gz 1
# pancreas_231.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_231.nii.gz 1
# pancreas_234.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_234.nii.gz 1
# pancreas_235.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_235.nii.gz 1
# pancreas_236.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_236.nii.gz 1
# pancreas_239.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_239.nii.gz 1
# pancreas_241.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_241.nii.gz 1
# pancreas_242.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_242.nii.gz 1
# pancreas_243.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_243.nii.gz 1
# pancreas_244.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_244.nii.gz 1
# pancreas_246.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_246.nii.gz 1
# pancreas_247.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_247.nii.gz 1
# pancreas_249.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_249.nii.gz 1
# pancreas_253.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_253.nii.gz 1
# pancreas_254.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_254.nii.gz 1
# pancreas_255.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_255.nii.gz 1
# pancreas_256.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_256.nii.gz 1
# pancreas_258.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_258.nii.gz 1
# pancreas_259.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_259.nii.gz 1
# pancreas_261.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_261.nii.gz 1
# pancreas_262.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_262.nii.gz 1
# pancreas_264.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_264.nii.gz 1
# pancreas_265.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_265.nii.gz 1
# pancreas_266.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_266.nii.gz 1
# pancreas_267.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_267.nii.gz 1
# pancreas_268.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_268.nii.gz 1
# pancreas_269.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_269.nii.gz 1
# pancreas_270.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_270.nii.gz 1
# pancreas_274.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_274.nii.gz 2
# pancreas_275.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_275.nii.gz 1
# pancreas_276.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_276.nii.gz 1
# pancreas_277.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_277.nii.gz 1
# pancreas_278.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_278.nii.gz 1
# pancreas_279.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_279.nii.gz 1
# pancreas_280.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_280.nii.gz 1
# pancreas_283.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_283.nii.gz 1
# pancreas_284.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_284.nii.gz 1
# pancreas_285.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_285.nii.gz 1
# pancreas_286.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_286.nii.gz 1
# pancreas_287.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_287.nii.gz 1
# pancreas_289.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_289.nii.gz 1
# pancreas_290.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_290.nii.gz 1
# pancreas_291.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_291.nii.gz 1
# pancreas_292.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_292.nii.gz 1
# pancreas_293.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_293.nii.gz 1
# pancreas_294.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_294.nii.gz 1
# pancreas_295.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_295.nii.gz 1
# pancreas_296.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_296.nii.gz 1
# pancreas_297.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_297.nii.gz 1
# pancreas_298.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_298.nii.gz 1
# pancreas_299.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_299.nii.gz 1
# pancreas_300.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_300.nii.gz 1
# pancreas_301.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_301.nii.gz 1
# pancreas_302.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_302.nii.gz 1
# pancreas_303.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_303.nii.gz 1
# pancreas_304.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_304.nii.gz 1
# pancreas_305.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_305.nii.gz 1
# pancreas_308.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_308.nii.gz 1
# pancreas_309.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_309.nii.gz 1
# pancreas_310.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_310.nii.gz 1
# pancreas_311.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_311.nii.gz 1
# pancreas_312.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_312.nii.gz 1
# pancreas_313.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_313.nii.gz 1
# pancreas_315.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_315.nii.gz 1
# pancreas_316.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_316.nii.gz 1
# pancreas_318.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_318.nii.gz 1
# pancreas_320.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_320.nii.gz 1
# pancreas_321.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_321.nii.gz 1
# pancreas_323.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_323.nii.gz 1
# pancreas_325.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_325.nii.gz 1
# pancreas_326.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_326.nii.gz 1
# pancreas_327.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_327.nii.gz 1
# pancreas_328.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_328.nii.gz 1
# pancreas_329.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_329.nii.gz 1
# pancreas_330.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_330.nii.gz 1
# pancreas_331.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_331.nii.gz 1
# pancreas_333.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_333.nii.gz 1
# pancreas_334.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_334.nii.gz 1
# pancreas_336.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_336.nii.gz 1
# pancreas_339.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_339.nii.gz 1
# pancreas_342.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_342.nii.gz 1
# pancreas_343.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_343.nii.gz 1
# pancreas_344.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_344.nii.gz 1
# pancreas_345.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_345.nii.gz 1
# pancreas_346.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_346.nii.gz 1
# pancreas_347.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_347.nii.gz 1
# pancreas_348.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_348.nii.gz 1
# pancreas_350.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_350.nii.gz 1
# pancreas_351.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_351.nii.gz 1
# pancreas_354.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_354.nii.gz 1
# pancreas_355.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_355.nii.gz 1
# pancreas_356.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_356.nii.gz 1
# pancreas_357.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_357.nii.gz 1
# pancreas_358.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_358.nii.gz 1
# pancreas_360.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_360.nii.gz 1
# pancreas_361.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_361.nii.gz 1
# pancreas_362.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_362.nii.gz 1
# pancreas_364.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_364.nii.gz 1
# pancreas_365.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_365.nii.gz 1
# pancreas_366.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_366.nii.gz 1
# pancreas_367.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_367.nii.gz 1
# pancreas_369.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_369.nii.gz 1
# pancreas_370.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_370.nii.gz 1
# pancreas_372.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_372.nii.gz 1
# pancreas_374.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_374.nii.gz 1
# pancreas_375.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_375.nii.gz 1
# pancreas_376.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_376.nii.gz 1
# pancreas_377.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_377.nii.gz 1
# pancreas_378.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_378.nii.gz 1
# pancreas_379.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_379.nii.gz 1
# pancreas_380.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_380.nii.gz 1
# pancreas_382.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_382.nii.gz 1
# pancreas_385.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_385.nii.gz 1
# pancreas_386.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_386.nii.gz 1
# pancreas_387.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_387.nii.gz 1
# pancreas_388.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_388.nii.gz 1
# pancreas_389.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_389.nii.gz 1
# pancreas_391.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_391.nii.gz 1
# pancreas_392.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_392.nii.gz 1
# pancreas_393.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_393.nii.gz 1
# pancreas_395.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_395.nii.gz 1
# pancreas_398.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_398.nii.gz 1
# pancreas_399.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_399.nii.gz 1
# pancreas_400.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_400.nii.gz 1
# pancreas_401.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_401.nii.gz 1
# pancreas_402.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_402.nii.gz 1
# pancreas_404.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_404.nii.gz 1
# pancreas_405.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_405.nii.gz 1
# pancreas_406.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_406.nii.gz 1
# pancreas_409.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_409.nii.gz 1
# pancreas_410.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_410.nii.gz 1
# pancreas_411.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_411.nii.gz 1
# pancreas_412.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_412.nii.gz 1
# pancreas_413.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_413.nii.gz 1
# pancreas_414.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_414.nii.gz 1
# pancreas_415.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_415.nii.gz 1
# pancreas_416.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_416.nii.gz 1
# pancreas_418.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_418.nii.gz 1
# pancreas_419.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_419.nii.gz 1
# pancreas_421.nii.gz
# C:\Users\ADMIN\Desktop\Workspace\Code\data\msd\Task07_Pancreas\labelsTr\pancreas_421.nii.gz 1

# %%
# Read the data frames
df3d = pd.read_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_3D_tumor_per_organ.csv')
df2d = pd.read_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_2D_tumor_per_organ.csv')

# %%
image_name_list_with_tumor = df3d.image_name.unique().tolist()
image_name_list_all_subjects = [f for f in data_dict.keys()]

subject_list = []
# Group by image name and iterate through the groups
for name, group in df3d.groupby('image_name'):
    subject_dict = {}
    # Number of tumors
    number_tumors_group = len(group)    
    max_tumor_size_group = max(group.major_axis_length_cm)
    cancer_stage = -1 # No Cancer
    # Get cancer stage
    # For details see: https://www.cancerresearchuk.org/about-cancer/pancreatic-cancer/stages-types-grades/tnm-staging
    # A very rough and oversimplified approximation using only tumor size, consider the following hypothetical rule:
    # Tumor size ≤ 2 cm: Approximate as Stage I (T1)
    # Tumor size > 2 cm and ≤ 4 cm: Approximate as Stage IIa (T2)
    # Tumor size > 4 cm and ≤ 6 cm: Approximate as Stage IIb (T3)
    # T3 means the cancer is bigger than 4cm but is still within the pancreas. (T4)
    # Please note that T staging also considers depth of invasion into the pancreas wall and surrounding structures, not just diameter size.
    # Here we will use fictional staging for 1, 2, 3

    # Stage 1
    if max_tumor_size_group < 2:
        cancer_stage = 1
    # Stage 2
    elif  max_tumor_size_group >= 2 and max_tumor_size_group < 4:
        cancer_stage = 2
    # Stage 3
    elif  max_tumor_size_group >= 4 and max_tumor_size_group < 6:
        cancer_stage = 3
    else:
    # Stage 4
        cancer_stage = 4


    subject_dict['name'] = name
    subject_dict['max_tumor_size'] = max_tumor_size_group
    subject_dict['number_tumors'] = number_tumors_group
    subject_dict['cancer_stage'] = cancer_stage
    
    subject_list.append(subject_dict.copy())

df_subject = pd.DataFrame(subject_list)
df_subject.to_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_3D_subject.csv', index=False)

# %%
# Distribution of tumor vs organ number where values are non-zero
df3d_organ = df3d.loc[:, df3d.columns.str.startswith('organ')]
# Remove columns with all zeros
df3d_organ = df3d_organ.loc[:, (df3d_organ != 0).any(axis=0)]

# # Remove columns with less than 400 voxel counts
df3d_organ = df3d_organ.loc[:, df3d_organ.sum() > 40000]

# print(df3d_organ.sum())

df3d_organ.sum().plot(kind='bar')
#10	pancreas

# Rename columns as follows: 
# organ 0 is backbround
# organ 3 is kidney_left	
# organ 6	stomach
# organ 10	pancreas
df3d_organ.columns = ['background', 'kidney left', 'stomach', 'pancreas']
df3d_organ.sum().plot(kind='bar')

# Normalize the number of voxels as cm3
# df3d_organ = df3d_organ.div(df3d_organ.sum(axis=1), axis=0)

# Plot histogram of number of voxels per organ normalized by total number of voxels
#df3d_organ.sum().plot(kind='bar', title='Percentage of voxel tumor count per organ')
# Out:
# <Axes: >

# %%
# Plot distribution of cancer stage for integer values vs tumor size
df_subject.plot.scatter(x='cancer_stage', y='max_tumor_size')

# Title
plt.title('Distribution of cancer stage vs tumor size for Liver')

# X label
plt.xlabel('Cancer Stage')

# Y label
plt.ylabel('Tumor Size (cm)')

# show file with maximum tumor size
df_subject.loc[df_subject['max_tumor_size'].idxmax()]
# Out:
# name              pancreas_415.nii.gz
# max_tumor_size              13.961877
# number_tumors                       1
# cancer_stage                        4
# Name: 276, dtype: object

# %%
df3d.columns
#Plot largest_tumor_length_cm histogram, where tumor_length_cm is less than 20cm and gretar than zero, using 100 bins
df3d[ (df3d.major_axis_length_cm > 0) &  (df3d.major_axis_length_cm < 20)].major_axis_length_cm.hist(bins=50)
# Title
plt.title("Histogram of largest 3D tumor length less than 20cm per subject")
# Y label
plt.ylabel("Frequency")
# X label
plt.xlabel("Tumor length (less than 20cm) per subject")
# Out:
# Text(0.5, 0, 'Tumor length (less than 20cm) per subject')

# %%
# cluster the tumor_area and number_of_tumors
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(df2d[['tumor_area_cm2', 'number_of_tumors']])
df2d['tumor_cluster'] = kmeans.predict(df2d[['tumor_area_cm2', 'number_of_tumors']])
df2d.plot.scatter(x='tumor_area_cm2', y='number_of_tumors', c='tumor_cluster', colormap='viridis')

# Axis title
plt.xlabel('Tumor area (cm^2)')
plt.ylabel('Number of tumors')
plt.title('Tumor area vs number of tumors')

# # show density plot of tumor_area and number_of_tumors
import seaborn as sns
sns.jointplot(x='tumor_area_cm2', y='number_of_tumors', data=df2d, kind='kde')

# Axis title
plt.xlabel('Tumor area (cm^2)')
plt.ylabel('Number of tumors')
plt.title('Tumor area vs number of tumors')
# Out:
# Text(0.5, 1.0, 'Tumor area vs number of tumors')

# %%
df2d['tumor_cluster'].value_counts()

# Get mean value of tumor_area and number_of_tumors for each cluster
df2d.groupby('tumor_cluster')[['tumor_area_cm2', 'number_of_tumors']].mean()
# Out:
#                tumor_area_cm2  number_of_tumors
# tumor_cluster
# 0                    3.363164          1.002588
# 1                   21.888680          1.000000
# 2                   80.193800          1.066667

# %%
df_subject = pd.read_csv(r'C:\Users\ADMIN\Desktop\Workspace\Code\data\msd_quantification\msd_pancreas_metrics_3D_subject.csv')
print(df_subject.columns)
# Plot scatter plot of tumor_area vs number_of_tumors where tumor_flag is 1
df_subject.plot.scatter(x='max_tumor_size', y='number_tumors')
# Axis title
plt.xlabel('Max tumor size (cm)')
plt.ylabel('Number of tumors')
plt.title('Tumor size (cm) vs Number of Tumors for Liver')
plt.ticklabel_format(style='plain')
# Out:
# Index(['name', 'max_tumor_size', 'number_tumors', 'cancer_stage'], dtype='object')
